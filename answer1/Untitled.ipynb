# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from PIL import Image

# %%
img1_grayscale = cv.imread('../Images/1/Car1.jpg',cv.IMREAD_GRAYSCALE)          # queryImage
img2_grayscale = cv.imread('../Images/1/Car2.jpg',cv.IMREAD_GRAYSCALE) # trainImage
# Initiate ORB detector
orb = cv.ORB_create()
# find the keypoints and descriptors with ORB
kp1, des1 = orb.detectAndCompute(img1_grayscale,None)
kp2, des2 = orb.detectAndCompute(img2_grayscale,None)

# %%
# create BFMatcher object
bf = cv.BFMatcher(cv.NORM_HAMMING, crossCheck=True)
# Match descriptors.
matches = bf.match(des1,des2)
# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)
# Draw 6 matches.
for i in range(165,185):
    print(str(i)+" : ")
    img3 = cv.drawMatches(img1_grayscale,kp1,img2_grayscale,kp2,matches[i:i+1],None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
    plt.imshow(img3),plt.show()
    cv.imwrite(f'./pts/matching_points{i}.jpg', img3)
# Out:
# 165 :
# 166 :
# 167 :
# 168 :
# 169 :
# 170 :
# 171 :
# 172 :
# 173 :
# 174 :
# 175 :
# 176 :
# 177 :
# 178 :
# 179 :
# 180 :
# 181 :
# 182 :
# 183 :
# 184 :
