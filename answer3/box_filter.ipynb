# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2
import importlib
import spatial_filter as sf # importing spatial filters library

# %%
importlib.reload(sf)
im1 = cv2.cvtColor(cv2.imread('../Images/3/Lena.bmp'), cv2.COLOR_BGR2GRAY)

# %%
box_filtered = sf.mean_filter(im1, 3)
plt.imshow(box_filtered, cmap="gray")

# %%
save_list = [40]
for i in range(1,41):
    
    plt.imshow(box_filtered, cmap="gray")
    if i in save_list:
        cv2.imwrite(f'box_results/mean3_{i}.jpg', box_filtered)
    box_filtered = sf.mean_filter(box_filtered, 3)
